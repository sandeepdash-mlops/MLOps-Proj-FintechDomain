# %%
import pandas as pd
import pymongo

df = pd.read_csv('data.csv')
df.head()
# Out:
#    id  Gender  Age  KYC_Verified  Region_Code  Previously_Onboarded  \
# 0   1    Male   44             1           28                     0
# 1   2    Male   76             1            3                     0
# 2   3    Male   47             1           28                     0
# 3   4    Male   21             1           11                     1
# 4   5  Female   29             1           41                     1
#
#   Account_Tenure Is_Fraud  Avg_Txn_Amt  Payment_Channel  Vintage  Response
# 0      > 2 Years      Yes        40454               26      217         1
# 1       1-2 Year       No        33536               26      183         0
# 2      > 2 Years      Yes        38294               26       27         1
# 3       < 1 Year       No        28619              152      203         0
# 4       < 1 Year       No        27496              152       39         0

# %%
# df should be converted into dict before we push it to mongodb

data = df.to_dict(orient='records')
# data  # To check data in dict format

# %%
DB_NAME = "Proj1"
COLLECTION_NAME = "Proj1-Data"
CONNECTION_URL = "mongodb+srv://sandeepdash043:KfJg81bgnEWytWCC@cluster0.mb72e4o.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# above, either remove your credentials or delete the mongoDB resource bofore pushing it to github.

# %%
client = pymongo.MongoClient(CONNECTION_URL)
data_base = client[DB_NAME]
collection = data_base[COLLECTION_NAME]

# To establish a connection with our mongodb setup

# %%
# Uploading data to MongoDB
rec = collection.insert_many(data)

# %%
## If you are getting timeout issue

# import certifi
# client = pymongo.MongoClient(CONNECTION_URL, tlsCAFile=certifi.where())
# # TO CREATE THE DATABASE
# data_base = client[DB_NAME]
# collection = data_base[COLLECTION_NAME]
# # TO INSERT DATA INTO THE COLLECTION
# rec = collection.insert_many(data)
